# %% [markdown]
# # Final EDA Summary Template
#
# This notebook is a short shared template for final EDA summaries. Each EDA section has only three parts: research question, features/methods, and main findings.
#
# Use the shared `df` loaded below when possible. If a section needs a different CSV, copy the loading cell inside that section and change the path there.

# %%
from pathlib import Path

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme(style="whitegrid")
pd.set_option("display.max_columns", 100)

PROJECT_ROOT = Path.cwd()
while PROJECT_ROOT.name != "summer26-pokemon-battle-predictor" and PROJECT_ROOT.parent != PROJECT_ROOT:
    PROJECT_ROOT = PROJECT_ROOT.parent

DATA_DIR = PROJECT_ROOT / "data"

# Tomorrow, change only this path if everyone is using the same parsed CSV.
PARSED_CSV_PATH = DATA_DIR / "data_cleaned.csv.zip"

print("Project root:", PROJECT_ROOT)
print("Parsed CSV path:", PARSED_CSV_PATH)
# Out:
# Project root: /Users/gknapp/Library/CloudStorage/GoogleDrive-gknapp@colby.edu/My Drive/Technology/Coding/Personal Notes/Erdos Institute/project/summer26-pokemon-battle-predictor
# Parsed CSV path: /Users/gknapp/Library/CloudStorage/GoogleDrive-gknapp@colby.edu/My Drive/Technology/Coding/Personal Notes/Erdos Institute/project/summer26-pokemon-battle-predictor/data/data_cleaned.csv.zip

# %%
# Load the shared dataframe.
# Uncomment after PARSED_CSV_PATH points to the correct file.

df = pd.read_csv(PARSED_CSV_PATH)
print(df.shape)
df.head()
# Out:
# (12778, 299)
#              format          id  p1_win  ratedQ  n_turns  start_time  \
# 0  gen9randombattle  2642076539       0    True       21  1782884765
# 1  gen9randombattle  2642074504       1    True        7  1782884343
# 2  gen9randombattle  2641921866       1   False       31  1782859109
# 3  gen9randombattle  2641831207       1    True       51  1782847154
# 4  gen9randombattle  2642210572       1    True       18  1782911409
#
#      end_time  duration          p1name  p1side  p1elo0  p1elo1       p2name  \
# 0  1782884937       172          Lirnom       1    1624    1607       Jenome
# 1  1782884385        42      jnpr010334       1    1651    1667      masajji
# 2  1782859432       323      realgreenz       1       0       0  ABIDTHEBEST
# 3  1782847410       256  soumatou_story       1    2113    2127   TheLastOne
# 4  1782911669       260           jobzy       1    1177    1201       danbur
#
#    p2side  p2elo0  p2elo1  type_diversity_diff  num_boosting_abilities_diff  \
# 0       2    1674    1691                    0                            0
# 1       2    1582    1566                   -1                           -1
# 2       2       0       0                    0                            0
# 3       2    2014    2000                   -2                           -2
# 4       2    1165    1141                    0                            2
#
#    num_move_boosters_diff  total_stat_diff  p1_total_adv  \
# 0                       1              -79      3.125322
# 1                      -2               19      0.997149
# 2                       1              129      5.479100
# 3                       2              347      3.903277
# 4                       1             -120      1.475808
#
#    p1_revealed_team_size  p2_revealed_team_size  M11_name M11_speciesId  \
# 0                      4                      5  Cyclizar      cyclizar
# 1                      2                      3  Virizion      virizion
# 2                      6                      6    Plusle        plusle
# 3                      6                      6  Tsareena      tsareena
# 4                      2                      6   Dewgong       dewgong
#
#    M11_used M11_gender  M11_shinyQ  M11_level      M11_ability  \
# 0         1          M       False         83      Regenerator
# 1         1          N       False         82        Justified
# 2         1          M       False         95    Lightning Rod
# 3         1          F       False         87  Queenly Majesty
# 4         1          M       False         94        Thick Fat
#
#            M11_item M11_teraType        M11_role      M11_mv1      M11_mv2  \
# 0  Heavy-Duty Boots       Dragon    Fast Support        taunt    rapidspin
# 1          Life Orb         Rock   Setup Sweeper    stoneedge  closecombat
# 2          Life Orb        Fairy   Setup Sweeper  thunderbolt    nastyplot
# 3      Choice Scarf        Steel    Fast Support   tripleaxel     knockoff
# 4      Assault Vest       Poison  Bulky Attacker     knockoff   tripleaxel
#
#        M11_mv3        M11_mv4 M11_type1 M11_type2  M11_hp  M11_atk  M11_def  \
# 0     shedtail    dracometeor    Dragon    Normal     252      205      156
# 1  swordsdance      leafblade     Grass  Fighting     283      195      165
# 2       encore  alluringvoice  Electric       NaN     268      100      130
# 3    powerwhip          uturn     Grass       NaN     267      259      220
# 4         surf       flipturn     Water       Ice     322      185      204
#
#    M11_spa  M11_spd  M11_spe  M11_off      M12_name M12_speciesId  M12_used  \
# 0      189      156      249      205     Cramorant     cramorant         1
# 1      195      259      224      195      Koraidon      koraidon         0
# 2      215      196      234      215     Hatterene     hatterene         1
# 3      137      220      175      259       Snorlax       snorlax         1
# 4      185      232      185      185  Iron Boulder   ironboulder         0
#
#   M12_gender  ...  M24_spa  M24_spd M24_spe M24_off      M25_name  \
# 0          M  ...      182      118     158     198      Tsareena
# 1          N  ...      199      141     141     250  Gouging Fire
# 2          F  ...      188      236     219     188     Passimian
# 3          F  ...      143      179     270     234    Hitmonchan
# 4          N  ...      152      170     195     256       Jirachi
#
#   M25_speciesId M25_used M25_gender M25_shinyQ M25_level      M25_ability  \
# 0      tsareena        1          F      False        87  Queenly Majesty
# 1   gougingfire        0          N      False        74   Protosynthesis
# 2     passimian        1          M      False        83          Defiant
# 3    hitmonchan        1          M      False        87        Iron Fist
# 4       jirachi        1          N      False        80     Serene Grace
#
#            M25_item  M25_teraType       M25_role     M25_mv1     M25_mv2  \
# 0          Life Orb         Steel   Fast Support  tripleaxel   synthesis
# 1  Heavy-Duty Boots         Fairy    Bulky Setup   heatcrash  morningsun
# 2         Leftovers         Steel    Bulky Setup    gunkshot      bulkup
# 3         Leftovers         Steel  Bulky Support      encore  drainpunch
# 4         Leftovers         Water   Fast Support    bodyslam    ironhead
#
#         M25_mv3      M25_mv4  M25_type1 M25_type2 M25_hp  M25_atk M25_def  \
# 0  highjumpkick    powerwhip      Grass       NaN    267      259     220
# 1       outrage  dragondance       Fire    Dragon    277      213     222
# 2    drainpunch     knockoff   Fighting       NaN    302      247     197
# 3      knockoff    poisonjab   Fighting       NaN    229      232     187
# 4       protect         wish      Steel   Psychic    291      206     206
#
#    M25_spa  M25_spd M25_spe M25_off     M26_name M26_speciesId M26_used  \
# 0      137      220     175     259   Toxtricity    toxtricity        1
# 1      139      181     178     213     Zangoose      zangoose        1
# 2      114      147     180     247     Tornadus      tornadus        1
# 3      111      241     182     232  Corviknight   corviknight        1
# 4      206      206     206     206       Kyogre        kyogre        1
#
#   M26_gender M26_shinyQ M26_level   M26_ability          M26_item  \
# 0          F      False        82     Punk Rock      Choice Specs
# 1          M      False        85   Toxic Boost         Toxic Orb
# 2          M      False        82     Prankster  Heavy-Duty Boots
# 3          M      False        80  Mirror Armor      Rocky Helmet
# 4          N      False        71       Drizzle      Choice Scarf
#
#    M26_teraType       M26_role     M26_mv1         M26_mv2      M26_mv3  \
# 0        Normal  Fast Attacker  sludgewave       boomburst   voltswitch
# 1        Normal  Fast Attacker    knockoff          facade  swordsdance
# 2        Flying  Fast Attacker   nastyplot  bleakwindstorm    grassknot
# 3        Dragon  Bulky Support       uturn       bodypress    bravebird
# 4         Water  Fast Attacker     thunder      waterspout  originpulse
#
#        M26_mv4  M26_type1 M26_type2 M26_hp  M26_atk M26_def  M26_spa  M26_spd  \
# 0    overdrive   Electric    Poison    257      165     162      234      162
# 1  closecombat     Normal       NaN    263      244     151      151      151
# 2   focusblast     Flying       NaN    264      193     162      252      178
# 3        roost     Flying     Steel    288      185     214      131      182
# 4      icebeam      Water       NaN    259      147     169      254      240
#
#   M26_spe M26_off
# 0     170     234
# 1     202     244
# 2     229     252
# 3     153     185
# 4     169     254
#
# [5 rows x 299 columns]

# %% [markdown]
# See `data/README.md` for a thorough description of the column headers.

# %% [markdown]
# ## 1. General Pokemon EDA

# %% [markdown]
# ### Research Question
#
# -

# %% [markdown]
# ### Features Looking Into And Methods
#
# Focus: General Pokemon stats, types, and team composition.
#
# -

# %% [markdown]
# ### Main Findings
#
# -

# %%
# Optional: create the key summary table or plot for this section.
# Use the shared df, or load a section-specific CSV here if needed.

# summary_table = ...
# summary_table

# %% [markdown]
# ## 2. First Pokemon Advantage EDA

# %% [markdown]
# ### Research Question
#
# -

# %% [markdown]
# ### Features Looking Into And Methods
#
# Focus: Opening Pokemon / first matchup advantage.
#
# -

# %% [markdown]
# ### Main Findings
#
# -

# %%
# Optional: create the key summary table or plot for this section.
# Use the shared df, or load a section-specific CSV here if needed.

# summary_table = ...
# summary_table

# %% [markdown]
# ## 3. Active Switch Count And Win Rate EDA

# %% [markdown]
# ### Research Question
#
# -

# %% [markdown]
# ### Features Looking Into And Methods
#
# Focus: Relationship between active switches during battle and win rate.
#
# -

# %% [markdown]
# ### Main Findings
#
# -

# %%
# Optional: create the key summary table or plot for this section.
# Use the shared df, or load a section-specific CSV here if needed.

# summary_table = ...
# summary_table

# %% [markdown]
# ## 4. Pokemon Advantage Stats EDA

# %% [markdown]
# ### Research Question
#
# -

# %% [markdown]
# ### Features Looking Into And Methods
#
# Focus: Pokemon advantage features and their relation to battle outcome.
#
# -

# %% [markdown]
# ### Main Findings
#
# -

# %%
# Optional: create the key summary table or plot for this section.
# Use the shared df, or load a section-specific CSV here if needed.

# summary_table = ...
# summary_table

# %% [markdown]
# # Overall Takeaways

# %% [markdown]
# ### Research Question
#
# What did the combined EDA work help us understand about Pokemon battle prediction?
#
# -

# %% [markdown]
# ### Features Looking Into And Methods
#
# -

# %% [markdown]
# ### Main Findings
#
# -
